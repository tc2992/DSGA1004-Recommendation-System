# %%
                                                                                                                                                                                                                                                        import pandas as pd
    import matplotlib.pyplot as plt

# %%
cd /Users/yili/Desktop/final
# Out:
# /Users/yili/Desktop/final

# %%
df = pd.read_csv('train01_eval.csv',header = None)

# %%
df.columns = ['maxIter','rank','reg_param','RMSE','MAP']
df.head()
# Out:
#    maxIter  rank  reg_param      RMSE       MAP
# 0      5.0   8.0      0.001  2.494765  0.882692
# 1      5.0   8.0      0.010  2.132366  0.882763
# 2      5.0   8.0      0.050  2.017619  0.882693
# 3      5.0   8.0      0.100  1.970317  0.882692
# 4      5.0   8.0      0.200  1.929453  0.882693

# %%
import seaborn as sns
grid = sns.FacetGrid(df, col="maxIter", hue = "rank", palette="tab20c", col_wrap=2)
grid.map(sns.lineplot,"reg_param", "RMSE")

# %%
grid = sns.FacetGrid(df, col="maxIter", hue = "rank", palette="tab20c", col_wrap=2)
grid.map(sns.lineplot,"reg_param", "MAP").add_legend()

# %%
min_rmse = df[['RMSE']].idxmin()

# %%
df.iloc[min_rmse,:]
# Out:
#      maxIter  rank  reg_param      RMSE       MAP
# 238     20.0  18.0        0.2  1.891896  0.882693

# %%
max_MAP = df[['MAP']].idxmax() 
df.iloc[max_MAP,:]
# Out:
#      maxIter  rank  reg_param      RMSE       MAP
# 244     20.0  20.0       0.01  2.144515  0.883758
